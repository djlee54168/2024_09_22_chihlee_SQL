# %% [markdown]
# # **富邦新一代API - Python範例程式碼**

# %% [markdown]
# # 安裝

# %% [markdown]
# ## 若已安裝過 SDK，可**忽略**此部分

# %% [markdown]
# ### 安裝新一代API Python SDK
# 此範例使用Windows版本檔案 <br>
# ***註:*** SDK檔案名稱 (ex. fubon_neo-1.0.3-cp37-abi3-win_amd64.whl) 請根據實際下載.whl名稱修改 <br>
# ***註2:*** SDK檔案需與本jupyter notebook檔案至於同一資料夾內，或是修改以下指令之SDK檔案路徑

# %%
# Pip install SDK
# !pip install --force-reinstall --no-cache fubon_neo-2.0.1-cp37-abi3-win_amd64.whl
# Out:
# Processing e:\文件\github\2024_09_22_chihlee_sql\lesson7\fubon_neo-2.0.1-cp37-abi3-win_amd64.whl
# Collecting websocket-client==1.5.1 (from fubon-neo==2.0.1)
#   Downloading websocket_client-1.5.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting pyee>=9.0.4 (from fubon-neo==2.0.1)
#   Downloading pyee-12.0.0-py3-none-any.whl.metadata (2.8 kB)
# Collecting typing-extensions (from pyee>=9.0.4->fubon-neo==2.0.1)
#   Downloading typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Downloading websocket_client-1.5.1-py3-none-any.whl (55 kB)
# Downloading pyee-12.0.0-py3-none-any.whl (14 kB)
# Downloading typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Installing collected packages: websocket-client, typing-extensions, pyee, fubon-neo
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.12.2
#     Uninstalling typing_extensions-4.12.2:
#       Successfully uninstalled typing_extensions-4.12.2
# Successfully installed fubon-neo-2.0.1 pyee-12.0.0 typing-extensions-4.12.2 websocket-client-1.5.1

# %% [markdown]
# # SDK 版本檢視

# %%
import fubon_neo

# %%
fubon_neo.__version__
# Out:
# '2.0.1'

# %% [markdown]
# # 準備

# %%
 # 匯入 SDK Library
from fubon_neo.sdk import FubonSDK, Order
from fubon_neo.constant import TimeInForce, OrderType, PriceType, MarketType, BSAction

# %%
# 連結 API Server
sdk = FubonSDK()

# %% [markdown]
# ## 登入

# %%
accounts = sdk.login("A121714564", "tzj1nez2wyyy", "C:\CAFubon\A121714564/A121714564.pfx", "tzj1nez2wyyy")   # 登入帳號 輸入:帳號、密碼、憑證路徑、憑證密碼
print(accounts)
# Out:
# Result {
#   is_success: True,
#   message: None,
#   data: [Account {
#     name: "李定洲",
#     branch_no: "20505",
#     account: "37089",
#     account_type: "stock",
# }]
# }

# %% [markdown]
# # 行情元件

# %% [markdown]
# ## **建立行情元件連線**

# %%
sdk.init_realtime() # 建立行情元件連線

# %% [markdown]
# ## 行情 WebSocket 報價

# %% [markdown]
# ### WebSocket callback functions 設定

# %%
import json
import traceback

subscribe_ids = []  # 訂閱頻道 id 列表

def handle_connect():  # 連線成功 callback
    print("行情連接成功")

def handle_disconnect(code, message):  # 連接斷線 callback
    print(f"行情連接斷線: {code}, {message}")

def handle_message(message): # 處理接收訊息 callback
    try:
        msg = json.loads(message)
        event = msg["event"]
        data = msg["data"]
    
        if event == "pong":
            return
        
        if event == "subscribed":
            id = data["id"]
            
            if id in subscribe_ids:
                print(f"Error: 訂閱 id {id} 已存在列表中")
            else:
                subscribe_ids.append(id)
    
        elif event == "unsubscribed":
            id = data["id"]
            
            try:
                subscribe_ids.remove(id)
            except:
                print(f"Error: 查無此筆訂閱 id 資料, id {id}")
    
        print(f'market data message: {message}')           
        
    except Exception as e:
        handle_error(f'Error parsing JSON: {e}', traceback.format_exc())

def handle_error(error,traceback_info=None):  # 處理程式錯誤訊息 callback
    print(f'market data error: {error}')
    if traceback_info:
        print(f'Traceback:\n{traceback_info}')

stock = sdk.marketdata.websocket_client.stock
stock.on("connect", handle_connect)
stock.on("message", handle_message)
stock.on("disconnect", handle_disconnect)
stock.on("error", handle_error)

stock.connect()  # WebSocket 連線
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 47
#      44     if traceback_info:
#      45         print(f'Traceback:\n{traceback_info}')
# ---> 47 stock = sdk.marketdata.websocket_client.stock
#      48 stock.on("connect", handle_connect)
#      49 stock.on("message", handle_message)
#
# AttributeError: 'FubonSDK' object has no attribute 'marketdata'

# %% [markdown]
# ###### 訂閱商品資料

# %%
# 訂閱股票最新成交資訊
stock.subscribe({ 
        "channel": 'trades', 
        "symbol": '1101',
        "intradayOddLot": True,
        })
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 # 訂閱股票最新成交資訊
# ----> 2 stock.subscribe({
#       3         "channel": 'trades',
#       4         "symbol": '1101',
#       5         "intradayOddLot": True,
#       6         })
#
# NameError: name 'stock' is not defined

# %%
# 訂閱股票最新最佳五檔委買委賣資訊
stock.subscribe({ 
    'channel': 'books', 
    'symbol': '2330'
})

# %%
# 訂閱股票最新指數行情資料
stock.subscribe({ 
    'channel': 'indices', 
    'symbol': 'IR0001'
})

# %%
target_id = "Dn90D2VM2McNXqzJx9gpsz5q8A460Qu2MA"  #欲取消訂閱之頻道編號(id)

result = stock.unsubscribe(
        {
          "id": target_id
        }
)

# %% [markdown]
# ### 斷開 WebSocket 連線

# %%
stock.disconnect()

# %% [markdown]
# ## 行情 WebAPI 查詢

# %%
# 建立行情查詢 WebAPI 連線 Object Instance
restStock = sdk.marketdata.rest_client.stock

# %% [markdown]
# ### 日內行情

# %%
# 股票或指數列表（依條件查詢）
result = restStock.intraday.tickers(type='EQUITY', exchange="TWSE", market="TSE")
stock_list = ["8467", "9103", "2330"]  # 抽樣查詢之股票 symbols

print(f"資料長度: {len(result['data'])}\n")

for ticker in result["data"]:
    if ticker["symbol"] in stock_list:
        print(ticker)
# Out:
# 資料長度: 1379
#
# {'symbol': '2330', 'name': '台積電'}
# {'symbol': '8467', 'name': '波力-KY'}
# {'symbol': '9103', 'name': '美德醫療-DR'}

# %%
# 取得股票資訊 (依股票代碼查詢)
result = restStock.intraday.ticker(symbol='2330')
print(result)
# Out:
# {'date': '2024-11-08', 'type': 'EQUITY', 'exchange': 'TWSE', 'market': 'TSE', 'symbol': '2330', 'name': '台積電', 'industry': '24', 'securityType': '01', 'previousClose': 1065, 'referencePrice': 1065, 'limitUpPrice': 1170, 'limitDownPrice': 959, 'canDayTrade': True, 'canBuyDayTrade': True, 'canBelowFlatMarginShortSell': True, 'canBelowFlatSBLShortSell': True, 'isAttention': False, 'isDisposition': False, 'isUnusuallyRecommended': False, 'isSpecificAbnormally': False, 'matchingInterval': 0, 'securityStatus': 'NORMAL', 'boardLot': 1000, 'tradingCurrency': 'TWD'}

# %%
# 股票即時報價（依代碼查詢）
result = restStock.intraday.quote(symbol="2330")
print(result)
# Out:
# {'date': '2024-11-08', 'type': 'EQUITY', 'exchange': 'TWSE', 'market': 'TSE', 'symbol': '2330', 'data': [{'price': 1090, 'volume': 16560, 'volumeAtBid': 0, 'volumeAtAsk': 16560}, {'price': 1085, 'volume': 18604, 'volumeAtBid': 9021, 'volumeAtAsk': 6235}, {'price': 1080, 'volume': 1280, 'volumeAtBid': 1280, 'volumeAtAsk': 0}]}

# %% [markdown]
# ### 行情快照

# %%
# 股票行情快照（依市場別）
result = restStock.snapshot.quotes(market='TSE')
print(result)
# Out:
# {'date': '2024-11-08', 'time': '140000', 'market': 'TSE', 'data': [{'type': 'EQUITY', 'symbol': '0050', 'name': '元大台灣50', 'openPrice': 199.4, 'highPrice': 200, 'lowPrice': 198.7, 'closePrice': 199, 'change': 1.55, 'changePercent': 0.79, 'tradeVolume': 12774, 'tradeValue': 2546347300, 'lastPrice': 199, 'lastUpdated': 1731043800000000}, {'type': 'EQUITY', 'symbol': '0051', 'name': '元大中型100', 'openPrice': 83.2, 'highPrice': 83.2, 'lowPrice': 82.1, 'closePrice': 82.15, 'change': -0.1, 'changePercent': -0.12, 'tradeVolume': 84, 'tradeValue': 6931250, 'lastPrice': 82.15, 'lastUpdated': 1731043800000000}, {'type': 'EQUITY', 'symbol': '0052', 'name': '富邦科技', 'openPrice': 197.2, 'highPrice': 198, 'lowPrice': 197, 'closePrice': 197.15, 'change': 1.95, 'changePercent': 1, 'tradeVolume': 1232, 'tradeValue': 243081650, 'lastPrice': 197.15, 'lastUpdated': 1731043800000000}, {'type': 'EQUITY', 'symbol': '0053', 'name': '元大電子', 'openPrice': 107.1, 'highPrice': 107.7, 'lowPrice': 106.9, 'closePrice': 107.3, 'change': 0.9, 'changePercent': 0.85, 'tradeVolume': 24, 'tradeValue': 2571750, 'lastPrice': 107.3, 'lastUpdated': 1731043800000000}, {'type': 'EQUITY', 'symbol': '0055', 'name': '元大MSCI金融', 'openPrice': 29.6, 'highPrice': 29.68, 'lowPrice': 29.5, 'closePrice': 29.55, 'change': 0.08, 'changePercent': 0.27, 'tradeVolume': 315, 'tradeValue': 9316630, 'lastPrice': 29.55, 'lastUpdated': 1731043800000000}, {'type': 'EQUITY', 'symbol': '0056', 'name': '元大高股息', 'openPrice': 38.3, 'highPrice': 38.45, 'lowPrice': 38.1, 'closePrice': 38.13, 'change': -0.03, 'changePercent': -0.08, 'tradeVolume': 19951, 'tradeValue': 763930440, 'lastPrice': 38.13, 'lastUpdated': 1731043800000000}, {'type': 'EQUITY', 'symbol': '0057', 'name': '富邦摩台', 'openPrice': 146.8, 'highPrice': 146.8, 'lowPrice': 146.35, 'closePrice': 146.5, 'change': 1.3, 'changePercent': 0.9, 'tradeVolume': 13, 'tradeValue': 1905150, 'lastPrice': 146.5, 'lastUpdated': 1731043800000000}, {'type': 'EQUITY', 'symbol': '0061', 'name': '元大寶滬深', 'openPrice': 20.68, 'highPrice': 20.93, 'lowPrice': 20.26, 'closePrice': 20.47, 'change': 0.19, 'changePercent': 0.94, 'tradeVolume': 2638, 'tradeValue': 54463210, 'lastPrice': 20.47, 'lastUpdated': 1731043800000000}, {'type': 'EQUITY', 'symbol': '006203', 'name': '元大MSCI台灣', 'openPrice': 94.1, 'highPrice': 94.1, 'lowPrice': 93.4, 'closePrice': 93.8, 'change': 0.95, 'changePercent': 1.02, 'tradeVolume': 7, 'tradeValue': 655900, 'lastPrice': 93.8, 'lastUpdated': 1731043800000000}, {'type': 'EQUITY', 'symbol': '006204', 'name': '永豐臺灣加權', 'openPrice': 118.1, 'highPrice': 118.2, 'lowPrice': 117.95, 'closePrice': 117.95, 'change': 0.5, 'changePercent': 0.43, 'tradeVolume': 5, 'tradeValue': 590550, 'lastPrice': 117.95, 'lastUpdated': 1731043800000000}, {'type': 'EQUITY', 'symbol': '006205', 'name': '富邦上証', 'openPrice': 35.16, 'highPrice': 35.59, 'lowPrice': 34.52, 'closePrice': 34.86, 'change': 0.41, 'changePercent': 1.19, 'tradeVolume': 1875, 'tradeValue': 65744240, 'lastPrice': 34.86, 'lastUpdated': 1731043800000000}, {'type': 'EQUITY', 'symbol': '006206', 'name': '元大上證50', 'openPrice': 33.33, 'highPrice': 33.62, 'lowPrice': 32.52, 'closePrice': 32.8, 'change': 0.15, 'changePercent': 0.46, 'tradeVolume': 534, 'tradeValue': 17671900, 'lastPrice': 32.8, 'lastUpdated': 1731043800000000}, {'type': 'EQUITY', 'symbol': '006207', 'name': '復華滬深', 'openPrice': 26.92, 'highPrice': 27.05, 'lowPrice': 26.36, 'closePrice': 26.62, 'change': 0.42, 'changePercent': 1.6, 'tradeVolume': 794, 'tradeValue': 21354570, 'lastPrice': 26.62, 'lastUpdated': 1731043800000000}, {'type': 'EQUITY', 'symbol': '006208', 'name': '富邦台50', 'openPrice': 116.45, 'highPrice': 116.9, 'lowPrice': 116.35, 'closePrice': 116.45, 'change': 1.05, 'changePercent': 0.91, 'tradeVolume': 10845, 'tradeValue': 1264781100, 'lastPrice': 116.45, 'lastUpdated': 1731043800000000}, {'type': 'EQUITY', 'symbol': '00625K', 'name': '富邦上証+R', 'openPrice': 7.89, 'highPrice': 7.89, 'lowPrice': 7.89, 'closePrice': 7.89, 'change ...

# %%
# 股票漲跌幅排行（依市場別）
result = restStock.snapshot.movers(market='TSE', direction='up', change='percent')
print(result)
# Out:
# {'date': '2024-11-08', 'time': '140000', 'market': 'TSE', 'change': 'percent', 'data': [{'type': 'EQUITY', 'symbol': '1587', 'name': '吉茂', 'openPrice': 38.85, 'highPrice': 42.6, 'lowPrice': 38.4, 'closePrice': 42.6, 'change': 3.85, 'changePercent': 9.94, 'tradeVolume': 1772, 'tradeValue': 73048200, 'lastPrice': 42.6, 'lastUpdated': 1731043800000000}, {'type': 'EQUITY', 'symbol': '4916', 'name': '事欣科', 'openPrice': 34.8, 'highPrice': 35.55, 'lowPrice': 34.05, 'closePrice': 35.55, 'change': 3.2, 'changePercent': 9.89, 'tradeVolume': 6483, 'tradeValue': 228630850, 'lastPrice': 35.55, 'lastUpdated': 1731043800000000}, {'type': 'EQUITY', 'symbol': '3706', 'name': '神達', 'openPrice': 52, 'highPrice': 54, 'lowPrice': 51, 'closePrice': 54, 'change': 4.85, 'changePercent': 9.87, 'tradeVolume': 92583, 'tradeValue': 4967377000, 'lastPrice': 54, 'lastUpdated': 1731043800000000}, {'type': 'EQUITY', 'symbol': '3419', 'name': '譁裕', 'openPrice': 17.6, 'highPrice': 18.4, 'lowPrice': 17.1, 'closePrice': 18.4, 'change': 1.65, 'changePercent': 9.85, 'tradeVolume': 3962, 'tradeValue': 72458300, 'lastPrice': 18.4, 'lastUpdated': 1731043800000000}, {'type': 'EQUITY', 'symbol': '1449', 'name': '佳和', 'openPrice': 25.95, 'highPrice': 26.85, 'lowPrice': 25.4, 'closePrice': 26.85, 'change': 2.4, 'changePercent': 9.82, 'tradeVolume': 14615, 'tradeValue': 385523850, 'lastPrice': 26.85, 'lastUpdated': 1731043800000000}, {'type': 'EQUITY', 'symbol': '2506', 'name': '太設', 'openPrice': 11.85, 'highPrice': 11.85, 'lowPrice': 11.85, 'closePrice': 11.85, 'change': 1.05, 'changePercent': 9.72, 'tradeVolume': 1777, 'tradeValue': 21057450, 'lastPrice': 11.85, 'lastUpdated': 1731043800000000}, {'type': 'EQUITY', 'symbol': '6781', 'name': 'AES-KY', 'openPrice': 615, 'highPrice': 667, 'lowPrice': 610, 'closePrice': 664, 'change': 57, 'changePercent': 9.39, 'tradeVolume': 4430, 'tradeValue': 2847953000, 'lastPrice': 664, 'lastUpdated': 1731043800000000}, {'type': 'EQUITY', 'symbol': '1795', 'name': '美時', 'openPrice': 270, 'highPrice': 286, 'lowPrice': 267, 'closePrice': 285, 'change': 24, 'changePercent': 9.2, 'tradeVolume': 10464, 'tradeValue': 2915505000, 'lastPrice': 285, 'lastUpdated': 1731043800000000}, {'type': 'EQUITY', 'symbol': '2495', 'name': '普安', 'openPrice': 36.5, 'highPrice': 38.95, 'lowPrice': 36.15, 'closePrice': 38.4, 'change': 2.8, 'changePercent': 7.87, 'tradeVolume': 16103, 'tradeValue': 611433700, 'lastPrice': 38.4, 'lastUpdated': 1731043800000000}, {'type': 'EQUITY', 'symbol': '3432', 'name': '台端', 'openPrice': 20.3, 'highPrice': 21.9, 'lowPrice': 20.1, 'closePrice': 21.5, 'change': 1.55, 'changePercent': 7.77, 'tradeVolume': 366, 'tradeValue': 7743750, 'lastPrice': 21.5, 'lastUpdated': 1731043800000000}, {'type': 'EQUITY', 'symbol': '3030', 'name': '德律', 'openPrice': 132, 'highPrice': 142.5, 'lowPrice': 132, 'closePrice': 140.5, 'change': 9.5, 'changePercent': 7.25, 'tradeVolume': 3758, 'tradeValue': 522927000, 'lastPrice': 140.5, 'lastUpdated': 1731043800000000}, {'type': 'EQUITY', 'symbol': '2069', 'name': '運錩', 'openPrice': 17.9, 'highPrice': 19.05, 'lowPrice': 17.85, 'closePrice': 18.6, 'change': 1.25, 'changePercent': 7.2, 'tradeVolume': 3703, 'tradeValue': 69459000, 'lastPrice': 18.6, 'lastUpdated': 1731043800000000}, {'type': 'EQUITY', 'symbol': '4967', 'name': '十銓', 'openPrice': 91.5, 'highPrice': 99.6, 'lowPrice': 90.7, 'closePrice': 97, 'change': 6.4, 'changePercent': 7.06, 'tradeVolume': 12993, 'tradeValue': 1258865000, 'lastPrice': 97, 'lastUpdated': 1731043800000000}, {'type': 'EQUITY', 'symbol': '2392', 'name': '正崴', 'openPrice': 72.3, 'highPrice': 76, 'lowPrice': 71, 'closePrice': 74.2, 'change': 4.7, 'changePercent': 6.76, 'tradeVolume': 62276, 'tradeValue': 4592498000, 'lastPrice': 74.2, 'lastUpdated': 1731043800000000}, {'type': 'EQUITY', 'symbol': '3312', 'name': '弘憶股', 'openPrice': 66.1, 'highPrice': 71.4, 'lowPrice': 65.1, 'closePrice': 69.9, 'change': 4.3, 'changePercent': 6.55, 'tradeVolume': 7588, 'tradeValue': 526731100, 'l ...

# %%
# 股票成交量值排行（依市場別）
result = restStock.snapshot.actives(market='TSE', trade='volume')
print(result)
# Out:
# {'date': '2024-11-08', 'time': '140000', 'market': 'TSE', 'trade': 'volume', 'data': [{'type': 'EQUITY', 'symbol': '00637L', 'name': '元大滬深300正2', 'openPrice': 18.13, 'highPrice': 18.38, 'lowPrice': 17.1, 'closePrice': 17.42, 'change': 0.26, 'changePercent': 1.52, 'tradeVolume': 238071, 'tradeValue': 4220040010, 'lastPrice': 17.42, 'lastUpdated': 1731043800000000}, {'type': 'EQUITY', 'symbol': '2354', 'name': '鴻準', 'openPrice': 98, 'highPrice': 99, 'lowPrice': 95.9, 'closePrice': 97.3, 'change': 1.4, 'changePercent': 1.46, 'tradeVolume': 194535, 'tradeValue': 18990024000, 'lastPrice': 97.3, 'lastUpdated': 1731043800000000}, {'type': 'EQUITY', 'symbol': '00632R', 'name': '元大台灣50反1', 'openPrice': 3.19, 'highPrice': 3.22, 'lowPrice': 3.18, 'closePrice': 3.21, 'change': -0.01, 'changePercent': -0.31, 'tradeVolume': 155705, 'tradeValue': 497944390, 'lastPrice': 3.21, 'lastUpdated': 1731043800000000}, {'type': 'EQUITY', 'symbol': '3062', 'name': '建漢', 'openPrice': 40.55, 'highPrice': 40.6, 'lowPrice': 36, 'closePrice': 36.3, 'change': -3.55, 'changePercent': -8.91, 'tradeVolume': 116225, 'tradeValue': 4428450750, 'lastPrice': 36.3, 'lastUpdated': 1731043800000000}, {'type': 'EQUITY', 'symbol': '3231', 'name': '緯創', 'openPrice': 121.5, 'highPrice': 125.5, 'lowPrice': 121, 'closePrice': 123.5, 'change': 3.5, 'changePercent': 2.92, 'tradeVolume': 113497, 'tradeValue': 14005343500, 'lastPrice': 123.5, 'lastUpdated': 1731043800000000}, {'type': 'EQUITY', 'symbol': '00680L', 'name': '元大美債20正2', 'openPrice': 8.17, 'highPrice': 8.24, 'lowPrice': 8.13, 'closePrice': 8.18, 'change': 0.12, 'changePercent': 1.49, 'tradeVolume': 112639, 'tradeValue': 921881380, 'lastPrice': 8.18, 'lastUpdated': 1731043800000000}, {'type': 'EQUITY', 'symbol': '00753L', 'name': '中信中國50正2', 'openPrice': 10.26, 'highPrice': 10.43, 'lowPrice': 9.81, 'closePrice': 9.99, 'change': 0.18, 'changePercent': 1.83, 'tradeVolume': 110038, 'tradeValue': 1114879450, 'lastPrice': 9.99, 'lastUpdated': 1731043800000000}, {'type': 'EQUITY', 'symbol': '00665L', 'name': '富邦恒生國企正2', 'openPrice': 9.37, 'highPrice': 9.45, 'lowPrice': 8.83, 'closePrice': 9.01, 'change': 0.16, 'changePercent': 1.81, 'tradeVolume': 104530, 'tradeValue': 958712930, 'lastPrice': 9.01, 'lastUpdated': 1731043800000000}, {'type': 'EQUITY', 'symbol': '3706', 'name': '神達', 'openPrice': 52, 'highPrice': 54, 'lowPrice': 51, 'closePrice': 54, 'change': 4.85, 'changePercent': 9.87, 'tradeVolume': 92583, 'tradeValue': 4967377000, 'lastPrice': 54, 'lastUpdated': 1731043800000000}, {'type': 'EQUITY', 'symbol': '2609', 'name': '陽明', 'openPrice': 70.7, 'highPrice': 73, 'lowPrice': 70.3, 'closePrice': 71.5, 'change': 1.8, 'changePercent': 2.58, 'tradeVolume': 82585, 'tradeValue': 5937697700, 'lastPrice': 71.5, 'lastUpdated': 1731043800000000}, {'type': 'EQUITY', 'symbol': '9105', 'name': '泰金寶-DR', 'openPrice': 6.9, 'highPrice': 7.03, 'lowPrice': 6.61, 'closePrice': 6.62, 'change': -0.17, 'changePercent': -2.5, 'tradeVolume': 82038, 'tradeValue': 558753620, 'lastPrice': 6.62, 'lastUpdated': 1731043800000000}, {'type': 'EQUITY', 'symbol': '2356', 'name': '英業達', 'openPrice': 53.3, 'highPrice': 54.1, 'lowPrice': 51.8, 'closePrice': 52.4, 'change': -0.1, 'changePercent': -0.19, 'tradeVolume': 75983, 'tradeValue': 4025737300, 'lastPrice': 52.4, 'lastUpdated': 1731043800000000}, {'type': 'EQUITY', 'symbol': '00878', 'name': '國泰永續高股息', 'openPrice': 23.4, 'highPrice': 23.4, 'lowPrice': 23.17, 'closePrice': 23.2, 'change': 0.01, 'changePercent': 0.04, 'tradeVolume': 68957, 'tradeValue': 1604577640, 'lastPrice': 23.2, 'lastUpdated': 1731043800000000}, {'type': 'EQUITY', 'symbol': '00929', 'name': '復華台灣科技優息', 'openPrice': 18.57, 'highPrice': 18.65, 'lowPrice': 18.36, 'closePrice': 18.4, 'change': -0.11, 'changePercent': -0.59, 'tradeVolume': 67443, 'tradeValue': 1246004560, 'lastPrice': 18.4, 'lastUpdated': 1731043800000000}, {'type': 'EQUITY', 'symbol': '2615', 'name': '萬海', 'openPrice': 93.4, 'highPrice': 97, 'lowPrice': 92.5, 'close ...

# %% [markdown]
# ### 歷史行情

# %%
# 取得 1 年內歷史股價（依代碼查詢）
# P.S. 目前分Ｋ無法指定開始日期（from） 與 結束日期（to），一律回傳近五日資料，並且無法選擇 turnover 與 change 的欄位
result = restStock.historical.candles(**{"symbol": "2330", "from": "2023-07-26", "to": "2024-01-30"})
print(result)
# Out:
close': 582, 'volume': 40580966}, {'date': '2023-12-13', 'open': 576, 'high': 579, 'low': 576, 'close': 577, 'volume': 24327758}, {'date': '2023-12-12', 'open': 580, 'high': 581, 'low': 575, 'close': 578, 'volume': 32856787}, {'date': '2023-12-11', 'open': 572, 'high': 575, 'low': 570, 'close': 574, 'volume': 29204446}, {'date': '2023-12-08', 'open': 574, 'high': 577, 'low': 570, 'close': 570, 'volume': 39243978}, {'date': '2023-12-07', 'open': 570, 'high': 573, 'low': 566, 'close': 566, 'volume': 24259384}, {'date': '2023-12-06', 'open': 568, 'high': 575, 'low': 568, 'close': 570, 'volume': 23116422}, {'date': '2023-12-05', 'open': 571, 'high': 572, 'low': 567, 'close': 570, 'volume': 27355530}, {'date': '2023-12-04', 'open': 582, 'high': 582, 'low': 571 ...

# %%
# 取得近 52 週股價數據（依代碼查詢）
result = restStock.historical.stats(symbol="2330")
print(result)

# %% [markdown]
# # 交易 (單筆)

# %% [markdown]
# ### 建立委託單

# %%
# 定義訂單內容
order = Order(
    buy_sell = BSAction.Buy,
    symbol = "2330",
    price = None,
    quantity = 1000, # 股數; 1000為一張
    market_type = MarketType.Common,
    price_type = PriceType.Reference,
    time_in_force = TimeInForce.ROD,
    order_type = OrderType.Stock,
    user_def = None, # optional field
);

# 列印訂單內容
print(order)

# %%
# 下單
order_reponse = sdk.stock.place_order(accounts.data[0], order)
print(order_reponse)

# %% [markdown]
# ### 取得委託單結果

# %%
result = sdk.stock.get_order_results(accounts.data[0])
print(f"筆數: {len(result.data)}")
i = 0
for order_result in result.data:
    print(f"第 {i+1} 筆:")
    print(order_result, end="\n\n")
    i += 1
# Out:
# 筆數: 2
# 第 1 筆:
# OrderResult {
#     function_type: None,
#     date: "2024/11/08",
#     seq_no: "00014995502",
#     branch_no: "20505",
#     account: "37089",
#     order_no: "o1464",
#     asset_type: 0,
#     market: "TAIEX",
#     market_type: Common,
#     stock_no: "1301",
#     buy_sell: Buy,
#     price_type: Limit,
#     price: 48.5,
#     quantity: 1000,
#     time_in_force: ROD,
#     order_type: Stock,
#     is_pre_order: false,
#     status: 50,
#     after_price_type: None,
#     after_price: 48.5,
#     unit: 1000,
#     after_qty: 1000,
#     filled_qty: 1000,
#     filled_money: 48500,
#     before_qty: None,
#     before_price: None,
#     user_def: " ",
#     last_time: "09:00:21.352",
#     details: None,
#     error_message: None,
# }
#
# 第 2 筆:
# OrderResult {
#     function_type: None,
#     date: "2024/11/08",
#     seq_no: "00014995650",
#     branch_no: "20505",
#     account: "37089",
#     order_no: "o1471",
#     asset_type: 0,
#     market: "TAIEX",
#     market_type: Common,
#     stock_no: "1301",
#     buy_sell: Buy,
#     price_type: Limit,
#     price: 48.7,
#     quantity: 1000,
#     time_in_force: ROD,
#     order_type: Stock,
#     is_pre_order: false,
#     status: 50,
#     after_price_type: None,
#     after_price: 48.7,
#     unit: 1000,
#     after_qty: 1000,
#     filled_qty: 1000,
#     filled_money: 48700,
#     before_qty: None,
#     before_price: None,
#     user_def: " ",
#     last_time: "09:00:17.231",
#     details: None,
#     error_message: None,
# }

# %% [markdown]
# #### 使用範例：使用委託書或流水序號取得特定委託單物件

# %%
def get_order_by_no(orders, order_or_seq_no, use_order_no=True):
    if orders.data is None:
        print(f"查無委託單資訊")
        return None

    for order in orders.data:
        if use_order_no:  # 以委託書號查詢
            if order.order_no is not None and order.order_no == order_or_seq_no:
                # print(f"提取委託單: {order}")
                return order
        else:  # 以委託單流水序號查詢
            if order.seq_no is not None and order.seq_no == order_or_seq_no:
                # print(f"提取委託單: {order}")
                return order

    # 查無委託單
    field_name = "委託書號" if use_order_no else "委託單流水序號"
    print(f"{field_name} {order_or_seq_no} 查無委託單")
    return None

# 使用範例 1: 以委託書號查詢
orders = sdk.stock.get_order_results(accounts.data[0])  # 查詢所有委託單
order = get_order_by_no(orders, "x0003", use_order_no=True)  # x0016 為目標委託書號
print(f"使用範例 1: 結果委託單 {order}\n")

# # 使用範例 2: 以委託單流水序號查詢
# orders = sdk.stock.get_order_results(accounts.data[0])  # 查詢所有委託單
# order2 = get_order_by_no(orders, "00000237234", use_order_no=False)  # 00000237234 為目標委託單流水序號
# print(f"使用範例 2: 結果委託單 {order2}")
# Out:
# 委託書號 x0003 查無委託單
# 使用範例 1: 結果委託單 None

# %% [markdown]
# ### 改價

# %%
# 使用範例：使用委託單號取得欲修改之委託單物件
target_order = None
target_order_number = "l0001"  # 欲查找之委託單號

response = sdk.stock.get_order_results(accounts.data[0])

if response.is_success:
    for order in response.data:
        if order.order_no == target_order_number:  # 取第一個狀態為成功的委託單為例
            target_order = order

    if target_order is not None:
        print(target_order)
    else:
        print(f"單號 {target_order_number}，查無委託單")

else:
    print("查無資料")
    print(f"response: {response}")

# %%
# 單筆改價
target_order = order
modify_price_obj = sdk.stock.make_modify_price_obj(target_order, "542",)  # 改價
response = sdk.stock.modify_price(accounts.data[0], modify_price_obj)  # 送出改價單

# 印出回應
# print(f"目標委託單:\n{target_order}\n")
print(f"修改回覆:\n{response}")

# %% [markdown]
# ### 改量

# %%
#單筆改量
target_order = order
modify_quantity_obj = sdk.stock.make_modify_quantity_obj(target_order, 1000)  # 改量
response = sdk.stock.modify_quantity(accounts.data[0], modify_quantity_obj)  # 送出改量單

# 印出回應
# print(f"目標委託單:\n{target_order}\n")
print(f"修改回覆:\n{response}")

# %% [markdown]
# #### 刪單

# %%
# 函數: 刪單 by 單號
def del_order(order_no, account):
    if not isinstance(order_no, str):
        print(f"請輸入單號字串，例如\"x0001\"")
        return None

    # 取得委託單 object
    target_order = None
    orders = sdk.stock.get_order_results(account)

    for order in orders.data:
        if order.order_no == order_no:
            target_order = order

    if target_order is None:
        print(f"查無目標委託單, 目標委託單號 {order_no}. 帳號:\n{account}")
        return None
    else:
        response = sdk.stock.cancel_order(account, target_order)
        print(f"刪單回報:\n{response}\n\n")
        return response

# 刪單
response = del_order("x0005", accounts.data[0])  # 可修改單號及帳號

if response is None:
    print("刪單函數執行錯誤")

else:
    target_order_number = response.data.order_no
    # 取得新的委託單資訊
    target_order = None
    orders = sdk.stock.get_order_results(accounts.data[0])
    for order in orders.data:
        if order.order_no == target_order_number:
            target_order = order
            
    if target_order is None:
        print(f"查無目標委託單。目標委託單號 {target_order_number}")
    else:
        print(f"新委託單資訊(單筆):\n{target_order}\n\nstatus: {target_order.status}")  # status 30 代表刪單成功

# %% [markdown]
# ### 查詢歷史委託

# %%
# 歷史委託
response = sdk.stock.order_history(accounts.data[0], "20240313", "20240313")  # 只供查詢兩日內之歷史資料

if response.is_success:
    
    order_history = response.data
    
    print(f"筆數: {len(order_history)}\n")

    i = 0
    for order_his in order_history:
        i += 1
        print(f"第 {i} 筆:\n{order_his}\n")
        
else:
    print("查尋錯誤")
    print(f"response: {response}")

# %% [markdown]
# ### 查詢歷史成交

# %%
# 歷史成交
result = sdk.stock.filled_history(accounts.data[0], "20240313", "20240313")  # 只供查詢兩日內之歷史資料
print(result)

# %% [markdown]
# ### 資券配額查詢

# %%
# 資券配額查詢
result = sdk.stock.margin_quota(accounts.data[0], "2330")
print(result)

# %% [markdown]
# ### 現冲券配額查詢

# %%
# 現冲券配額查詢
result = sdk.stock.daytrade_and_stock_info(accounts.data[0], "2330")
print(result)

# %% [markdown]
# # 交易 (批次)

# %% [markdown]
# ### 建立批次委託單

# %%
# 建立欲委託清單
orders = [
  Order(
    buy_sell = BSAction.Buy,
    symbol = "2881",
    price = None,
    quantity = 2000,
    market_type = MarketType.Common,
    price_type = PriceType.LimitDown,
    time_in_force = TimeInForce.ROD,
    order_type = OrderType.Stock,
    user_def = "batch1" # optional field
), Order(
    buy_sell = BSAction.Buy,
    symbol = "1101",
    price = None,
    quantity = 1000,
    market_type = MarketType.Common,
    price_type = PriceType.LimitDown,
    time_in_force = TimeInForce.ROD,
    order_type = OrderType.Stock,
    user_def = "batch2" # optional field
) ]

orders

# %%
# 建立批次委託單
result = sdk.stock.batch_place_order(accounts.data[0], orders)
print(result)

# %% [markdown]
# ### 取得批次委託送單紀錄

# %% [markdown]
# ***註：*** 此僅為送單紀錄，無交易狀態更新

# %%
# 取得批次委託列表
result = sdk.stock.batch_order_lists(accounts.data[0])
print(result)

# %% [markdown]
# ### 取得批次委託送單紀錄明細

# %% [markdown]
# ***註：*** 此僅為送單紀錄，無交易狀態更新

# %%
# 取得批次委託列表
batch_list = sdk.stock.batch_order_lists(accounts.data[0])

# 取得單筆批次委託明細
target_batch_result = batch_list.data[0]  # 單筆批次委託結果
result = sdk.stock.batch_order_detail(accounts.data[0], target_batch_result)

print(result)

# %% [markdown]
# ### 批次修改

# %%
# 查詢委託單
response = sdk.stock.get_order_results(accounts.data[0])

# 取得此前批次下單(同Timestamp)成功之委託單
result_orders = []

if not response.is_success:
    print(f"委託單查詢失敗, 查詢結果:\n{orders}")

else:  # 委託單查詢成功
    for order in response.data:
        if (order.user_def is not None) and (str(timestamp) in order.user_def):
            result_orders.append(order)

# 列印
print(f"取得委託單結果:\n{result_orders}")

# %% [markdown]
# #### 批次修改委託價格

# %%
# 建立批次委託修改物件
modify_objects = []

for order in result_orders:
    the_price = order.after_price

    # 設定擬改價格 (自動設定預修改，僅為測試範例)
    if (the_price * 100) % 10 > 0:
        to_be_price = round(the_price + 0.05, 2)
    elif (the_price * 10) % 10 > 0:
        to_be_price = round(the_price + 0.1, 1)
    else:
        to_be_price = round(the_price + 1)

    # 建立改價 obj
    the_modify_price_obj = sdk.stock.make_modify_price_obj(order, str(to_be_price))
    print(f"委託單編號 {order.order_no}, 現價 {the_price}, 擬改價 {to_be_price}")

    # 放入批次列表
    modify_objects.append(the_modify_price_obj)

# 開始批次改價
if len(modify_objects) > 0:
    modified_results = sdk.stock.batch_modify_price(accounts.data[0], modify_objects)
    
    # 處理批次修改委託價格回傳結果
    if modified_results.is_success:
        print("修改成功")
        print(modified_results.data)
    else:
        print("修改失敗", modified_results.message)

else:
    print("改價列表為空白")

# %% [markdown]
# #### 批次修改委託數量

# %%
# 查詢委託單
response = sdk.stock.get_order_results(accounts.data[0])

# 取得此前批次下單(同Timestamp)成功之委託單
result_orders = []

if not response.is_success:
    print(f"委託單查詢失敗, 查詢結果:\n{orders}")

else:  # 委託單查詢成功
    for order in response.data:
        if (order.user_def is not None) and (str(timestamp) in order.user_def):
            result_orders.append(order)

# 列印
print(f"取得委託單結果:\n{result_orders}")

# %%
# 建立批次委託修改物件
modify_objects = []

for order in result_orders:
    the_qty = order.after_qty

    if the_qty > 1000:
        to_be_qty = the_qty - 1000
        
        # 建立改價 obj
        the_modify_price_obj = sdk.stock.make_modify_quantity_obj(order, int(to_be_qty))
        print(f"委託單編號 {order.order_no}, 現量 {the_qty}, 擬改量 {to_be_qty}")
    
        # 放入批次列表
        modify_objects.append(the_modify_price_obj)

    else:
        print(f"委託單編號 {order.order_no}, 現量 {the_price}, 現量不足，略過")

# 開始批次改量
if len(modify_objects) > 0:
    modified_results = sdk.stock.batch_modify_quantity(accounts.data[0], modify_objects)
    
    # 處理批次修改委託量回傳結果
    if modified_results.is_success:
        print("修改成功")
        print(modified_results.data)
    else:
        print("修改失敗", modified_results.message)

else:
    print("改價列表為空白，出問題了!")

# %% [markdown]
# #### 刪除批次委託單

# %%
# 查詢委託單
response = sdk.stock.get_order_results(accounts.data[0])

# 取得此前批次下單(同Timestamp)成功之委託單
result_orders = []

if not response.is_success:
    print(f"委託單查詢失敗, 查詢結果:\n{orders}")

else:  # 委託單查詢成功
    for order in response.data:
        if (order.user_def is not None) and (str(timestamp) in order.user_def):
            result_orders.append(order)

# 列印
print(f"取得委託單結果:\n{result_orders}")

# %%
for order in result_orders:
    print(f"擬刪除之委託單編號 {order.order_no}\n")

# 開始批次刪除
if len(result_orders) > 0:
    cancel_result = sdk.stock.batch_cancel_order(accounts.data[0], result_orders)
    
    # 處理批次刪除回傳結果
    if cancel_result.is_success:
        print("刪除成功")
        print(cancel_result.data)
    else:
        print("刪除失敗", cancel_result.message)

# %% [markdown]
# # 帳務

# %%
# 顯示帳號資訊
accounts.data[0]

# %% [markdown]
# ### 庫存查詢

# %%
# 庫存查詢
result = sdk.accounting.inventories(accounts.data[0])

if result.is_success:
    print(f"資料筆數: {len(result.data)}\n")
    i = 0
    for inv in result.data:
        i += 1
        print(f"第 {i} 筆\n")
        print(f"{inv}\n")
        
else:
    print("查詢失敗")
    print(result)

# %% [markdown]
# ### 未實現損益

# %%
# 未實現損益
result = sdk.accounting.unrealized_gains_and_loses(accounts.data[0])
print(result)
# Out:
# Result {
#   is_success: True,
#   message: None,
#   data: [UnrealizedData {
#     date: "2024/11/11",
#     branch_no: "20505",
#     account: "37089",
#     stock_no: "00919",
#     buy_sell: Buy,
#     order_type: Stock,
#     cost_price: 23.419,
#     tradable_qty: 35000,
#     today_qty: 35000,
#     unrealized_profit: 0,
#     unrealized_loss: 5094,
# }, UnrealizedData {
#     date: "2024/11/11",
#     branch_no: "20505",
#     account: "37089",
#     stock_no: "00940",
#     buy_sell: Buy,
#     order_type: Stock,
#     cost_price: 9.2524,
#     tradable_qty: 100000,
#     today_qty: 100000,
#     unrealized_profit: 27443,
#     unrealized_loss: 0,
# }, UnrealizedData {
#     date: "2024/11/11",
#     branch_no: "20505",
#     account: "37089",
#     stock_no: "1101",
#     buy_sell: Buy,
#     order_type: Stock,
#     cost_price: 33.156,
#     tradable_qty: 40000,
#     today_qty: 40000,
#     unrealized_profit: 0,
#     unrealized_loss: 55887,
# }, UnrealizedData {
#     date: "2024/11/11",
#     branch_no: "20505",
#     account: "37089",
#     stock_no: "1301",
#     buy_sell: Buy,
#     order_type: Stock,
#     cost_price: 48.669,
#     tradable_qty: 2000,
#     today_qty: 2000,
#     unrealized_profit: 0,
#     unrealized_loss: 2359,
# }, UnrealizedData {
#     date: "2024/11/11",
#     branch_no: "20505",
#     account: "37089",
#     stock_no: "2883",
#     buy_sell: Buy,
#     order_type: Stock,
#     cost_price: 10.1885,
#     tradable_qty: 100000,
#     today_qty: 100000,
#     unrealized_profit: 698516,
#     unrealized_loss: 0,
# }]
# }

# %% [markdown]
# ### 已實現損益

# %%
# 已實現損益
result = sdk.accounting.realized_gains_and_loses(accounts.data[0])
print(result)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # 已實現損益
# ----> 2 result = sdk.accounting.realized_gains_and_loses(accounts.data[0])
#       3 print(result)
#
# NameError: name 'sdk' is not defined

# %% [markdown]
# ### 維持率查詢

# %%
# 維持率
result = sdk.accounting.maintenance(accounts.data[0])
print(result)

# %% [markdown]
# ### 交割款查詢

# %%
# 交割款
result = sdk.accounting.query_settlement(accounts.data[0],"3d")
print(result)

# %% [markdown]
# ### 銀行餘額查詢

# %%
# 銀行餘額
result = sdk.accounting.bank_remain(accounts.data[0])
print(result)
# Out:
# Result {
#   is_success: True,
#   message: None,
#   data: BankRemain {
#     branch_no: "20505",
#     account: "37089",
#     currency: "TWD",
#     balance: 945140,
#     available_balance: 945140,
# }
# }

# %% [markdown]
# # 交易/帳務 主動回報

# %%
import time
import os 

# A callback to receive quote data
def on_order(err, content):
    print("==下單主動回報==")
    print(f"錯誤訊息 {err}")
    print(f"內容 {content}")
    print("========")
    
sdk.set_on_order(on_order) 

# A callback to receive quote data
def on_order_changed(err, content):
    print("==改單主動回報==")
    print(f"錯誤訊息 {err}")
    print(f"內容 {content}")
    print("========")
    
sdk.set_on_order_changed(on_order_changed) 

def on_filled(err, content):
    print("==成交主動回報==")
    print(f"錯誤訊息 {err}")
    print(f"內容 {content}")
    print("========")
    
sdk.set_on_filled(on_filled)

# A callback to receive quote data
def on_event(err, content):
    print("==事件主動回報==")
    print(f"錯誤訊息 {err}")
    print(f"內容 {content}")
    print("========")
    
sdk.set_on_event(on_event)
